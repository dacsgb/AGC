# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
distance, pulses = np.loadtxt("data.txt",unpack=True,delimiter=",",skiprows=1)

# %%
plt.figure(1)
plt.plot(pulses,distance,"o")
plt.ylabel("Distance - [m]")
plt.xlabel("Pulses")
plt.show()

# %%
fit = np.poly1d(np.polyfit(pulses,distance,1))
print(fit)
# Out:
#
# 0.005623 x - 0.9816
